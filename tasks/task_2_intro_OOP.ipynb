# %% [markdown]
# # Введение в методы анализа данных. Язык Python.

# %% [markdown]
# ## Домашняя работа 2: Процедурный подход к написанию программ. ООП. Паттерны проектирвания
# <br><br><br><br>
# __Ксемидов Борис (nstalker.anonim@yandex.ru)__
#
# __Аксентьев Артем (bworkboris@yandex.ru)__
#
#
# <br>

# %% [markdown]
# __Выдана__: 17.03.2024<br>
# __Deadline__: 24.03.2024 23:59
#
# Готовые решения отправлять на почту akseart@ya.ru и bworkboris@yandex.ru
#
# Готовое решение состоит из одного файла с расширением .ipynb с именем в виде <Ваше ФИО>\_task\_\<N\>.ipynb
#
#
# __Тема письма:__ "Домашние задания Python 03_2024"

# %% [markdown]
# __ФИО:__ <span style="color:red"> ... </span>

# %% [markdown]
# ## Критерии оценивания:
# - Правильность исполнения кода
# - Корректное исполнение на граничных случаях
# - Соблюдение PEP-8 и именования переменных
#
# Всего за работу можно получить 25 баллов.
#
# Изменение формулировок заданий, удаление фрагментов заданий запрещено.
#
# Все ячейки должны быть "выполненными". Под каждую задачу выполнена проверка.
#
# При заимствовании кода из интернета, необходимо указать ссылку на ресурс.

# %% [markdown]
# # Зачет
#
# Для выставления оценки за зачет, необходимо руководствоваться следующей таблицей:
#
# | Оценка | Необходимый балл |
# |--------|------------------|
# | 5      | 75               |
# | 4      | 65               |
# | 3      | 55               |

# %% [markdown]
# **Задание 1.** (2 балла)
#
# Реализуйте функцию на вход которой дан массив целых чисел.
# Для данного массива определена операция прибавления к первым k элементам единицы и только она. То есть к нескольким первым элементам массива можно прибавить 1 неограниченное число раз.
# Определить возможно ли уравнять все значения в массиве и если возможно за какое количество шагов?
#
# Функция должна возвращать кортеж значений, первый элемент которого показывает возможно ли выполнить заданное условие, а второй элемент либо None, если невозможно, либо количество шагов для достижения заданного условия.
#
# Пример:
#
# ```python
# [1, 2, 3, 4] -> [4, 4, 4, 4] -> (True, 3)
#
# 1 шаг [1, 2, 3, 4] -> [2, 3, 4, 4]
# 2 шаг [2, 3, 4, 4] -> [3, 4, 4, 4]
# 3 шаг [4, 4, 4, 4] -> [4, 4, 4, 4]
# ```

# %%
def task_01(array):
    ...

task_01([])

# %% [markdown]
# __Задание 2.__  (3 балла)
#
# Необходимо написать функцию, которая будет принимать две строки и определять можно ли составить из символов первой строки вторую строку.
#
# ```
# Hello, Hell -> True
# Hello, Hel -> True
# Hel, Hell -> False
# ```

# %%
def task_02(str1, str2):
    ...

task_02("", "")

# %% [markdown]
# **Задание 3.** (5 баллов)
#
# На основе заданного текстового файла создать новый файл, который будет содержать в каждой строке количество символов и количество слов в строке из первого файла, а также в конце файла необходимо дописать количество строк.
#
# Пример:
#
# Входной файл:
# ```
# QWERT.UI OP PO
# ASDF,FG
# ZX
# ```
#
# Выходной файл:
# ```
# 14 4
# 7 2
# 2 1
# ```
#
# __Примечание:__  в качестве разделителя слов может выступать символ пробела, запятой, а также точки. В подсчет символов входят так же символы разделители, но не входят скрытые символы, такие как символ переноса строки, в том числе пробельные символы в конце строки

# %%
def get_info_for_file(path_to_file1, path_to_file2):
    ...

#QWERT.UI OP PO
# ASDF,FG
# ZX
get_info_for_file("file.txt", "out_file.txt")

# %% [markdown]
# **Задание 4.** (6 балла)
#
# В некоторой компании используется git сервер для обмена кодом между разными членами команды. В рамках системы git существует понятие коммита, некоего "снимка" состояния кода в определенный момент времени. Также как и в любой хорошей компании существует набор тестов, однако тесты достаточно сложны, чтобы их запускать для каждого коммита, поэтому их запускают с некоторой регулярностью и проверяют сразу набор коммитов. Известно, что коммит который сломал тест, так же ломает тесты и всех последующих за ним коммитов.
#
# Ваша задача имитировать систему поиска ломающего коммита.
#
# На __вход функции__ подается массив состояний коммитов состоящий из логических элементов, где значение True обозначет, что данный коммит не ломает тест, а значение False, соответственно ломает. Гарантируется, что существует хотя бы один не ломающий коммит и хотя бы один ломающий
#
# На __выходе функции__ должен быть <u>номер(не индекс в массиве)  первого ломающего</u> коммита. За каждый шаг работы функция может проверить одновременно 2 элемента.
#
# __Примечание:__ Количество коммитов для проверки может быть очень большим ($10^6$), а количество шагов выполняемой вашей программой ограничено 25(для получения полного количества баллов).

# %% [markdown]
# __Пример входных и выходных данных:__
# [True, True, True, True, True, False, False, False, False, False, False, False, False, False, False] -> 6

# %%
def find_breaking_commit(commits):
    ...

find_breaking_commit([])

# %% [markdown]
# **Задание 5.** (4 балла)
#
# Реализуйте класс для одномерного вектора целых чисел (int) с любым количеством элементов.
#
# Примеры векторов:
# - $[1, 2, 3]$;
# - $[5, 2]$;
# - $[1]$;
# - $[0, 9, 6, 3]$.

# %%
class Vector:
    def __init__(self, list_num):
        """Инициализатор вектора.

        Аргументы:
            list_num (list): список целых чисел.
        """
        
        pass

    def shape(self):
        """Длина вектора (количество элементов в нем).

        Возвращает:
            целое число (int)
        """

        pass

    def add(self, other):
        """Сложение двух векторов (поэлементное) 

        Пример:
        [1, 2, 3] + [4, 5, 6] = [5, 7, 9]

        Аргументы:
            other (Vector): второй вектор этого же класса для сложения

        Возвращает:
            Vector: новый объект этого же класса, но с результами этого сложения
        """

        pass

    def mul(self, other):
        """ Умножение двух векторов (поэлементное)

        Аргументы:
            other (Vector): второй вектор этого же класса для умножения

        Возвращает:
            Vector: новый объект этого же класса, но с результами этого умножения
        """

        pass

    def get_values(self):
        """Возвращает вектор в виде строки для вывода в print.

        Возвращает:
            строка (str): вектор в виде строки (подряд идущие элементы вектор, выведенные красиво)
        """

        pass

    def setitem(self, key, value):
        """Заменить элемент с номером key значением value

        Аргументы:
            key (int): индекс для установки значения
            value (int): значение

        Возвращает:
            ничего не возвращает
        """

        pass

    def getitem(self, item):
        """Получить значение по номеру элемента вектора

        Аргументы:
            item (int): номер (индекс) элемента вектора

        Возвращает:
            целое число (int): значение элемента с номером item
        """

        pass


vec1 = Vector([1, 3, 2])
vec2 = Vector([1, 3, 4])
vec3 = vec1.add(vec2)
print(vec3.get_values())

# %% [markdown]
# **Задание 6.**  (5 балла)
#
# Реализуйте класс для двумерной матрицы целых чисел (int).
#
# Пример:
# $[
#     [1, 2, 3],
#     [4, 5, 6],
#     [7, 8, 9]
# ]$

# %%
class Matrix:
    def __init__(self, list_num):
        """Инициализатор матрицы.

        Аргументы:
            list_num (list): двумерный список целых чисел.
        """
        
        pass

    def shape(self):
        """Размерность матрицы (количество строк и столбцов в ней).

        Возвращает:
            кортеж из двух целых чисел: первое - количество строк, второе - столбцов
        """

        pass

    def add(self, other):
        """Сложение двух матриц (поэлементное) 

        Пример:
        [[1, 2, 3], [4, 5, 6]] + [[1, 1, 1], [2, 2, 2]] = [[2, 3, 4], [6, 7, 8]]

        Аргументы:
            other (Matrix): второй вектор этого же класса для сложения

        Возвращает:
            Matrix: новый объект этого же класса, но с результами этого сложения
        """

        pass

    def mul(self, other):
        """ Умножение двух матриц (поэлементное)

        Аргументы:
            other (Matrix): второй вектор этого же класса для умножения

        Возвращает:
            Matrix: новый объект этого же класса, но с результами этого умножения
        """

        pass

    def get_values(self):
        """Возвращает матрицу в виде строки для вывода в print.

        Возвращает:
            строка (str): матрица в виде строки (подряд идущие элементы матрицы, выведенные красиво)
        """

        pass

    def setitem(self, key1, key2, value):
        """Заменить элемент с номерами key1 по строке и key2 по столбцу значением value

        Аргументы:
            key1 (int): номер строки
            key2 (int): номер столбца
            value (int): значение

        Возвращает:
            ничего не возвращает
        """

        pass

    def getitem(self, key1, key2):
        """Получить значение по номерам элемента матрицы

        Аргументы:
            key1 (int): номер строки
            key2 (int): номер столбца

        Возвращает:
            целое число (int): значение элемента с номерами
        """

        pass


mat1 = Matrix([[1, 3, 2], [1, 1, 1]])
mat2 = Matrix([[1, 3, 4], [1, 3, 4]])
mat3 = mat1.add(mat2)
print(mat3.get_values())
